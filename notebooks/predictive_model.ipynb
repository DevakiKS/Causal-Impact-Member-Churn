# %%
import pandas as pd
import numpy as np
import os
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
from sklearn.metrics import roc_auc_score, f1_score, brier_score_loss, precision_recall_curve
from sklearn.utils import class_weight
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Dropout, Input

def run_predictive_model(data_path):
    # Load dataset
    df = pd.read_csv(data_path, low_memory=False)
    df = df.loc[:, ~df.columns.str.contains("Unnamed")]
    df["morbidity_index"] = pd.to_numeric(df["morbidity_index"], errors="coerce")
    
    # Drop rows with missing values in important columns including features and target
    feature_cols = ["zusatzbeitrag", "zusatzbeitrag_avg", "morbidity_index", "marktanteil versicherte", "insured_lag"]
    df_subset = df.dropna(subset=feature_cols + ["churn_rate", "treatment_flag"])
    
    # Extract features and target
    X = df_subset[feature_cols]
    y = df_subset["churn_rate"]
    
    # Binarize target: churn if churn_rate > 0.05
    y_binary = (y > 0.05).astype(int)
    
    # Check class distribution
    print("Class distribution in target:")
    print(y_binary.value_counts())
    
    # Split train/test data (stratify to maintain class balance)
    X_train, X_test, y_train, y_test = train_test_split(
        X, y_binary, test_size=0.2, random_state=42, stratify=y_binary
    )
    
    # Confirm no NaNs in train/test splits
    print("Any NaNs in X_train?", np.isnan(X_train).any())
    print("Any NaNs in X_test?", np.isnan(X_test).any())
    
    # Scale features
    scaler = StandardScaler()
    X_train_scaled = scaler.fit_transform(X_train)
    X_test_scaled = scaler.transform(X_test)
    
    # Check for NaNs after scaling (should not be any)
    print("Any NaNs in X_train_scaled?", np.isnan(X_train_scaled).any())
    print("Any NaNs in X_test_scaled?", np.isnan(X_test_scaled).any())
    
    # Compute class weights for imbalance
    class_weights = class_weight.compute_class_weight(
        'balanced',
        classes=np.unique(y_train),
        y=y_train
    )
    class_weights_dict = dict(enumerate(class_weights))
    print("Class weights:", class_weights_dict)
    
    # Build model with dropout for regularization
    model = Sequential([
        Input(shape=(X_train_scaled.shape[1],)),
        Dense(64, activation='relu'),
        Dropout(0.3),
        Dense(32, activation='relu'),
        Dropout(0.3),
        Dense(1, activation='sigmoid')
    ])
    
    model.compile(optimizer='adam', loss='binary_crossentropy', metrics=['accuracy'])
    
    # Train model
    history = model.fit(
        X_train_scaled,
        y_train,
        epochs=50,
        batch_size=32,
        validation_split=0.2,
        class_weight=class_weights_dict,
        verbose=2
    )
    
    # Predict probabilities on test set
    y_pred_prob = model.predict(X_test_scaled).flatten()
    
    # Check for NaNs in predictions
    print("Any NaNs in predicted probabilities?", np.isnan(y_pred_prob).any())
    
    # Find best threshold by maximizing F1 score on test set
    precisions, recalls, thresholds = precision_recall_curve(y_test, y_pred_prob)
    f1_scores = 2 * (precisions * recalls) / (precisions + recalls + 1e-8)
    best_idx = np.argmax(f1_scores)
    best_thresh = thresholds[best_idx]
    
    print(f"Best threshold by F1 score on test set: {best_thresh:.4f}")
    print(f"F1 score at best threshold: {f1_scores[best_idx]:.4f}")
    
    # Compute final metrics using best threshold
    y_pred_class = (y_pred_prob >= best_thresh).astype(int)
    print("ROC-AUC:", roc_auc_score(y_test, y_pred_prob))
    print("F1 Score:", f1_score(y_test, y_pred_class))
    print("Brier Score:", brier_score_loss(y_test, y_pred_prob))

    # Save prediction result for dashboard export
    # Save processed file
    notebooks_dir = os.path.dirname(os.path.abspath(__file__))
    project_root = os.path.abspath(os.path.join(notebooks_dir, '..'))
    target_dir = os.path.join(project_root, 'dashboard', 'data')
    os.makedirs(target_dir, exist_ok=True)

    nn_results_df = pd.DataFrame({
    "Actual Churn": y_test,
    "Predicted Probability": y_pred_prob,
    "Predicted Churn": y_pred_class})

    nn_results_df.to_excel(os.path.join(target_dir, "nn_prediction_results.xlsx"), index=False)

if __name__ == "__main__":
    data_path = "../data/processed/merged_panel_clean_data.csv"
    run_predictive_model(data_path)
# Out:
# Class distribution in target:
# churn_rate
# 0    15196
# 1        6
# Name: count, dtype: int64
# Any NaNs in X_train? zusatzbeitrag              False
# zusatzbeitrag_avg          False
# morbidity_index            False
# marktanteil versicherte    False
# insured_lag                False
# dtype: bool
# Any NaNs in X_test? zusatzbeitrag              False
# zusatzbeitrag_avg          False
# morbidity_index            False
# marktanteil versicherte    False
# insured_lag                False
# dtype: bool
# Any NaNs in X_train_scaled? False
# Any NaNs in X_test_scaled? False
# Class weights: {0: 0.5002056597564989, 1: 1216.1}
# Epoch 1/50
# 304/304 - 1s - 2ms/step - accuracy: 0.9906 - loss: 2.4271 - val_accuracy: 1.0000 - val_loss: 0.0103
# Epoch 2/50
# 304/304 - 0s - 453us/step - accuracy: 0.9995 - loss: 4.1102 - val_accuracy: 1.0000 - val_loss: 0.0259
# Epoch 3/50
# 304/304 - 0s - 483us/step - accuracy: 0.9995 - loss: 3.4592 - val_accuracy: 1.0000 - val_loss: 0.0434
# Epoch 4/50
# 304/304 - 0s - 506us/step - accuracy: 0.9983 - loss: 1.7771 - val_accuracy: 1.0000 - val_loss: 0.0937
# Epoch 5/50
# 304/304 - 0s - 473us/step - accuracy: 0.9916 - loss: 1.0466 - val_accuracy: 1.0000 - val_loss: 0.1186
# Epoch 6/50
# 304/304 - 0s - 458us/step - accuracy: 0.9717 - loss: 1.3058 - val_accuracy: 1.0000 - val_loss: 0.0762
# Epoch 7/50
# 304/304 - 0s - 488us/step - accuracy: 0.9507 - loss: 1.2928 - val_accuracy: 1.0000 - val_loss: 0.1453
# Epoch 8/50
# 304/304 - 0s - 498us/step - accuracy: 0.9134 - loss: 1.1055 - val_accuracy: 0.9363 - val_loss: 0.2077
# Epoch 9/50
# 304/304 - 0s - 472us/step - accuracy: 0.8698 - loss: 0.7584 - val_accuracy: 0.8890 - val_loss: 0.2613
# Epoch 10/50
# 304/304 - 0s - 483us/step - accuracy: 0.8279 - loss: 0.5702 - val_accuracy: 0.8689 - val_loss: 0.2696
# Epoch 11/50
# 304/304 - 0s - 494us/step - accuracy: 0.7786 - loss: 0.7462 - val_accuracy: 0.8183 - val_loss: 0.3259
# Epoch 12/50
# 304/304 - 0s - 448us/step - accuracy: 0.7719 - loss: 0.5572 - val_accuracy: 0.7497 - val_loss: 0.3855
# Epoch 13/50
# 304/304 - 0s - 476us/step - accuracy: 0.7295 - loss: 0.3922 - val_accuracy: 0.7637 - val_loss: 0.3743
# Epoch 14/50
# 304/304 - 0s - 499us/step - accuracy: 0.7506 - loss: 0.3348 - val_accuracy: 0.7850 - val_loss: 0.3496
# Epoch 15/50
# 304/304 - 0s - 470us/step - accuracy: 0.7473 - loss: 0.5678 - val_accuracy: 0.7690 - val_loss: 0.3764
# Epoch 16/50
# 304/304 - 0s - 459us/step - accuracy: 0.7379 - loss: 0.3830 - val_accuracy: 0.7707 - val_loss: 0.3815
# Epoch 17/50
# 304/304 - 0s - 505us/step - accuracy: 0.7525 - loss: 0.3686 - val_accuracy: 0.7908 - val_loss: 0.3500
# Epoch 18/50
# 304/304 - 0s - 491us/step - accuracy: 0.7887 - loss: 0.4427 - val_accuracy: 0.7550 - val_loss: 0.3951
# Epoch 19/50
# 304/304 - 0s - 475us/step - accuracy: 0.7623 - loss: 0.3088 - val_accuracy: 0.7986 - val_loss: 0.3239
# Epoch 20/50
# 304/304 - 0s - 554us/step - accuracy: 0.7838 - loss: 0.3127 - val_accuracy: 0.8311 - val_loss: 0.3012
# Epoch 21/50
# 304/304 - 0s - 540us/step - accuracy: 0.8162 - loss: 0.2926 - val_accuracy: 0.8640 - val_loss: 0.2615
# Epoch 22/50
# 304/304 - 0s - 449us/step - accuracy: 0.8223 - loss: 0.2820 - val_accuracy: 0.8640 - val_loss: 0.2537
# Epoch 23/50
# 304/304 - 0s - 450us/step - accuracy: 0.8559 - loss: 0.2202 - val_accuracy: 0.8890 - val_loss: 0.2238
# Epoch 24/50
# 304/304 - 0s - 451us/step - accuracy: 0.8635 - loss: 0.2307 - val_accuracy: 0.8948 - val_loss: 0.2044
# Epoch 25/50
# 304/304 - 0s - 448us/step - accuracy: 0.8772 - loss: 0.1738 - val_accuracy: 0.9301 - val_loss: 0.1517
# Epoch 26/50
# 304/304 - 0s - 448us/step - accuracy: 0.8777 - loss: 0.2354 - val_accuracy: 0.9211 - val_loss: 0.1688
# Epoch 27/50
# 304/304 - 0s - 468us/step - accuracy: 0.8987 - loss: 0.2099 - val_accuracy: 0.9503 - val_loss: 0.1473
# Epoch 28/50
# 304/304 - 0s - 504us/step - accuracy: 0.8856 - loss: 0.3233 - val_accuracy: 0.9026 - val_loss: 0.1963
# Epoch 29/50
# 304/304 - 0s - 497us/step - accuracy: 0.8761 - loss: 0.1997 - val_accuracy: 0.9108 - val_loss: 0.1761
# Epoch 30/50
# 304/304 - 0s - 497us/step - accuracy: 0.8941 - loss: 0.2503 - val_accuracy: 0.8853 - val_loss: 0.2671
# Epoch 31/50
# 304/304 - 0s - 483us/step - accuracy: 0.8703 - loss: 0.3359 - val_accuracy: 0.8709 - val_loss: 0.2505
# Epoch 32/50
# 304/304 - 0s - 473us/step - accuracy: 0.8779 - loss: 0.1825 - val_accuracy: 0.8931 - val_loss: 0.2154
# Epoch 33/50
# 304/304 - 0s - 468us/step - accuracy: 0.8759 - loss: 0.1675 - val_accuracy: 0.9223 - val_loss: 0.1625
# Epoch 34/50
# 304/304 - 0s - 448us/step - accuracy: 0.9134 - loss: 0.3195 - val_accuracy: 0.9001 - val_loss: 0.2125
# Epoch 35/50
# 304/304 - 0s - 452us/step - accuracy: 0.9001 - loss: 0.1971 - val_accuracy: 0.9022 - val_loss: 0.2137
# Epoch 36/50
# 304/304 - 0s - 470us/step - accuracy: 0.9012 - loss: 0.1435 - val_accuracy: 0.9462 - val_loss: 0.1506
# Epoch 37/50
# 304/304 - 0s - 494us/step - accuracy: 0.9327 - loss: 0.1243 - val_accuracy: 0.9688 - val_loss: 0.1032
# Epoch 38/50
# 304/304 - 0s - 539us/step - accuracy: 0.9573 - loss: 0.0998 - val_accuracy: 0.9766 - val_loss: 0.0932
# Epoch 39/50
# 304/304 - 0s - 482us/step - accuracy: 0.9324 - loss: 0.4909 - val_accuracy: 0.9207 - val_loss: 0.2335
# Epoch 40/50
# 304/304 - 0s - 471us/step - accuracy: 0.8960 - loss: 0.2167 - val_accuracy: 0.8964 - val_loss: 0.2186
# Epoch 41/50
# 304/304 - 0s - 453us/step - accuracy: 0.8900 - loss: 0.2199 - val_accuracy: 0.8956 - val_loss: 0.2038
# Epoch 42/50
# 304/304 - 0s - 450us/step - accuracy: 0.9214 - loss: 0.3324 - val_accuracy: 0.8956 - val_loss: 0.2282
# Epoch 43/50
# 304/304 - 0s - 451us/step - accuracy: 0.8940 - loss: 0.1983 - val_accuracy: 0.9330 - val_loss: 0.1970
# Epoch 44/50
# 304/304 - 0s - 449us/step - accuracy: 0.9275 - loss: 0.1229 - val_accuracy: 0.9593 - val_loss: 0.1325
# Epoch 45/50
# 304/304 - 0s - 453us/step - accuracy: 0.9455 - loss: 0.1670 - val_accuracy: 0.9651 - val_loss: 0.1325
# Epoch 46/50
# 304/304 - 0s - 447us/step - accuracy: 0.9463 - loss: 0.1892 - val_accuracy: 0.9630 - val_loss: 0.1440
# Epoch 47/50
# 304/304 - 0s - 449us/step - accuracy: 0.9392 - loss: 0.1403 - val_accuracy: 0.9663 - val_loss: 0.1370
# Epoch 48/50
# 304/304 - 0s - 447us/step - accuracy: 0.9446 - loss: 0.1018 - val_accuracy: 0.9762 - val_loss: 0.0893
# Epoch 49/50
# 304/304 - 0s - 463us/step - accuracy: 0.9444 - loss: 0.1216 - val_accuracy: 0.9741 - val_loss: 0.1089
# Epoch 50/50
# 304/304 - 0s - 460us/step - accuracy: 0.9476 - loss: 0.2283 - val_accuracy: 0.9675 - val_loss: 0.1279
# 96/96 ━━━━━━━━━━━━━━━━━━━━ 0s 330us/step
# Any NaNs in predicted probabilities? False
# Best threshold by F1 score on test set: 0.8942
# F1 score at best threshold: 0.0400
# ROC-AUC: 0.9842105263157894
# F1 Score: 0.04
# Brier Score: 0.03099905387741556
